# %% [markdown]
# # Lectura de archivos
#
#
# Semana Tec
#
# Profesores: Luz Eunice Angeles /José Ignacio Treviño

# %% [markdown]
# Qué aprenderemos:
#
# - Subir archivos desde el sistema de archivos local
# - Descargar archivos en el slistema de archivos local
# - Acceder a google drive
#   - Activarlo de en el entorno de ejecución
#   - Usar una API : PyDrive
# - Crear y leer datos de google sheets

# %% [markdown]
# ## Subir archivos desde el sistema de archivos local
#
# <code>files.upload</code> es usado para cargar los archivos y conocer el diccionario de los archivos que se cargaron.
# El diccionario está codificado según el nombre de archivo y los valores son los datos que se subieron.

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-76a289b5-ec3b-4da0-9320-9117ae712bea" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-76a289b5-ec3b-4da0-9320-9117ae712bea">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving airlines.csv to airlines.csv
# User uploaded file "airlines.csv" with length 386 bytes

# %% [markdown]
# ## Descargar archivos en el sistema de archivos local
#
# <code>files.download</code> invocará una descarga del archivo desde el navegador a tu computadora local.

# %%
from google.colab import files

with open('example.txt', 'w') as f:
  f.write('some content')

files.download('example.txt')

# %%
ls
# Out:
# airlines.csv  sample_data/  tmdb_5000_movies.csv

# %% [markdown]
# # Google Drive
#
# Puedes acceder a archivos en Drive de varias maneras, incluidas las siguientes:
# - Activación de Google Drive en la máquina virtual del entorno de ejecución
# - Usar un wrapper alrededor de la API, como <a href="https://gsuitedevs.github.io/PyDrive/docs/build/html/index.html">PyDrive</a>
# - Usar la <a href="https://developers.google.com/drive/v3/web/about-sdk">API nativa de REST</a>
#
#
#
# Puedes ver ejemplos de cada caso más abajo.

# %% [markdown]
# ## Activar Google Drive de forma local
#
# El ejemplo siguiente muestra cómo activar Google Drive en el entorno de ejecución mediante un código de autorización y cómo escribir y leer archivos allí. Una vez ejecutado, podrás ver el archivo nuevo &#40;<code>foo.txt</code>&#41; en <a href="https://drive.google.com/">https://drive.google.com/</a>.
#
# Ten en cuenta que solo se puede leer, escribir o mover archivos.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
with open('/content/drive/My Drive/SemanaTec/foo.txt', 'w') as f:
  f.write('Hello Google Drive!')
# !cat /content/drive/My\ Drive/semanaTec/foo.txt
# Out:
# cat: '/content/drive/My Drive/semanaTec/foo.txt': No such file or directory

# %% [markdown]
# ## PyDrive
#
# En los ejemplos que aparecen a continuación, se muestran la autenticación y la carga y descarga de archivos mediante PyDrive. Puedes encontrar más ejemplos en la <a href="https://gsuitedevs.github.io/PyDrive/docs/build/html/index.html">documentación de PyDrive</a>.

# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# %% [markdown]
# Autentica y crea el cliente de PyDrive.

# %%
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %% [markdown]
# Lista de ids de cada carpeta que tenemos en el google drive

# %%
file_list = drive.ListFile({'q': "'root' in parents and trashed=false"}).GetList()
for file1 in file_list:       
    print ('title: %s, id: %s' % (file1['title'], file1['id']))
# Out:
# title: SemanaTec, id: 1-2ZS0lNB_4clNeaItYmb3sRUH62Us8Rq
# title: semana tec arte analitica, id: 1pfMuYHeZ8WBWFlI31T-GTMgUwowzGTRl
# title: Act 1.2 Manejo de Consola, id: 1HlHu7_ZLvXbyDXWilh-2Ovz8BlpKHLf56naoGms2uZg
# title: Evidencia MA1033, id: 18TZA46P31R6YCRKQy-C8-VlGEFmFJgOBa8TjFKPGA3w
# title: zoom_0.mp4, id: 1HXH8VXd2q2J8_QKw7OLHHbWd243mWgRO
# title: Tarea 2 ecuaciones diferenciales , id: 1ZLC0Hp7Cg441ovsBHZVKYZLrgtizlu96
# title: Notas ecuaciones diferencialds, id: 1X9SJ7XFBCPzh91peJBXSIiKhoxESamwX
# title: Examen, id: 1Vbgmqj4KQcPZMZXAogthGX9nD8oMw7K3
# title: Tarea 1 ecuaciones diferenciales, id: 1ORg4g6UjLBxQZvUVowp7y471ostBWaxB
# title: Ecuaciones diferenciales 2.2, id: 14tqAm1q3fgIxNOhZ2qkjIIIx2aNOMUOg
# title: Ecuaciones diferenciales 2.1, id: 14S-Dg3IUTUb5i0SSj9UHPuL62NQh28br
# title: Ecuaciones diferenciales 1.1, id: 13ubKuzEX41l2qxDcLSsaltGPjpy5yK4Y
# title: Calculo vectorial, id: 13Ti-yJGQ7ESNaJjsd63ur9RlRPdhnP13
# title: Documento sin título, id: 1eLSYVBDYF0HRSOB-IREUJMxCoVvvivb7SRvUAlhFvxI
# title: main2, id: 1HnG2l5Agza2f8s4MQUB09b-nLun1_82v
# title: AVANCE 1 Modelación computacional de sistemas electromagnéticos, id: 1NZLSkwLnEgK-7sTA4wE9ioPvY8ZzlfluN6CIdOuZ2c4
# title: Tarea 1 Experimentando con la ley de Biot Savart, id: 1BrJfSzrhl1PioyY4I-Q9wgdtO-SKpPy5xjPXV037CMo
# title: 20210512_165635.jpg, id: 1wdgIhVtr1CV6nFaYr0KV443gva4MyOs6
# title: Evidencia 2 biologia computacional, id: 1lWth_Nmc5kCJIfWmtc1JIZR4Ne2RGmgjuCjNwmT4b8Y
# title: My Video.mp4, id: 15o9cx6zD4MTU31vwIWwJ_TJoHoxA1YPv
# title: videos biologica computacional.zip, id: 16ULSiJ6njMVpfOSZVv1FFxSjMnqPXrHt
# title: 20210418_234646.jpg, id: 1nIHMAk18E5zyZ12MiwmCeruHo26zKR_-
# title: 20210418_234653.jpg, id: 1nEqJTwWeALT7BPCeL_XInHTzkhfdVK8q
# title: 20210418_234707.jpg, id: 1n81aN1hj-9Q3XKgMZe1GEJSqugi_n8Ms
# title: 20210418_234711.jpg, id: 1n3HB3QBFOnT517xNiyqaUzlDU49jUlDn
# title: Actividad en clase | Base de datos de virus de NCBI, id: 1hjMrX_-rg0l25E3BFDTngs9apEmizTNfT4PUJGkHfYg
# title: voltios fotos 2.PNG, id: 1UZIESff0IVGkTRNb10Kldrp1WhTn6-mZ
# title: Voltios foto.PNG, id: 1Li49YoRMvCLLS83k7sN01yVLH0c8mRtK
# title: Actividad en clase | Analogía computadora y la célula, id: 1DCqHW2Y-v69Cfd47gM7xJBC5UNkWiDuvC42VwJblcjk
# title: Fichas de resumen A00831346, id: 17ia-HTTD84qdRg886BXktVOSq8POTDVRTwwACrku4BU
# title: 20210402_203354.jpg, id: 1ix1-LRevCyhBA2AVUpf3g7JhY7Gxb1mz
# title: 20210402_203407.jpg, id: 1iqaRJop61sNmsHjil-OxOX9PWHBLUOiu
# title: 20210402_203420.jpg, id: 1ipu74jaNz-BFUwO4-s_WoGgqjXUYbih1
# title: 20210402_203401.jpg, id: 1irx033rIxBl0tr0eVRs0wLACR89Y55Y7
# title: zoom_3.mp4, id: 1MhxH9tZp4G5oJDgmdUN1R0gMiLWuc_3q
# title: Video_GitHub.mp4, id: 1dWXhFh2noBkGWCmcDqt0wNyHrLNQEp8z
# title: VID-20210319-WA0004.mp4, id: 1dEcrhAH0ZTysmDc-Li6xvjnqXIHiynE_
# title: VID-20210319-WA0003.mp4, id: 1dElqqS70ogmeM5jYWB0bEXfbG62MnQmG
# title: VID-20210319-WA0002.mp4, id: 1dFXwcRvRyDJ0d0mAsmMw5C2zZo-1rX8m
# title: Video Diseño de Reto.mp4, id: 1N3TYfZsi5x404a--Wp1eK5VuF1xATrj8
# title: Circuito - Equipo 7, id: 1nY6c6dUvNSRU29LsW6rfYVlE_u1ljVIF2nFqUPelz6I
# title: Bitacora Etapa 2 - Equipo 7, id: 1NaFcLFNT-I2RyHGyLpCeSP6tbN41834kK6ifi19dI78
# title: IFE Eduardo Arvizu (1).pdf, id: 148bOdfamyk8WGulLGxNKTymhGUYc9ip7
# title: Responsiva.pdf, id: 1SvHDj7RM6m9AzbAUYcn1nJW_VqLJxFuQ
# title: Codigo.pdf, id: 1b2fANAXHdeUASSb1e_epEpehy-Zgc_ov
# title: Responsiva.pdf, id: 1JzGU-2e8I2PL_QurJfGMk-ej5Zq4PwiR
# title: Curp Julio Arvizu.pdf, id: 1Bp_SOjivAG1PMDIajEDe21YbwjKe3QA9
# title: Certificado de Preparatoria.pdf, id: 13I79CQftwcAfOSNw-njvleaHMQJo5uRZ
# title: Certificado de Preparatoria.pdf, id: 1is9rZ4XvIFg3dHI51lSDTGD1cs8IFUax
# title: Acta nacimiento Julio Arvizu.pdf, id: 13Ble2oUIG3JCiOlIvYPQ7t2lF0Kmt4La
# title: A00831346_miplandevidayITC_Terminado, id: 16SLyWzwbZnvxWQ5AoTRL8_t5yxbuaH77
# title: Segunda Entrega del Reto, id: 1bPdwFpab3oIz0UUWFhqcGvarRSEVdTfcPKv0Xqajorg
# title: Actividad_Energía_Renovable_México_A00831346, id: 1LKjUVoBWSMFcrV1d6ZskM8pragoChgrc9EA-9HmBJ-E
# title: Actividad_Energía_Renovable_México_A00831346.pdf, id: 1lkkmNG28Dz3U9snhlpftsbEeQE1SQmMG
# title: Proyecto de ciencia, id: 1Xj-vgYYC4zlJVf-uFAU_hWUQBGyk01aiGkICmm8tbb8
# title: Reto_Innovador.py, id: 1CCyjiR96MeB0BlKyifzSh7JSCyGvAV1R
# title: Rueda de la Vida(1), id: 1ZQwJTeQ18uMjKteMaef6nTOx7_MFAQlBSA-OfBc9NUs
# title: Rueda de la Vida(1), id: 1ElQz3YVja5c-iYyyfxPqyTxF8EsyDSVwqwGf-ehOp_Q
# title: Rueda de la Vida(1).xlsx, id: 1dL8fYc6AmdoS9zeObEZhQviyPQU1Nf_i
# title: A00831346, id: 1p4vWp-8CT9GFy5uSYZhQ28kvI61taHvu
# title: Video Plan de desarrollo A00831346.mp4, id: 1_mWyS7JolTNQMJu58Ts9cf28Zn_vjoWb
# title: Reto_EQUIPO5.xlsx, id: 1LLXglNFyHqMkg4sEC8RRPo91XBlkdNVH
# title: Reto_equipo5.mp4, id: 1TjEV-B9oCpWfkb8BHxbaTaIwl5awRmcv

# %%
fid= '1-2ZS0lNB_4clNeaItYmb3sRUH62Us8Rq'

# %% [markdown]
# Crea y sube un archivo de texto.

# %%
uploaded = drive.CreateFile({'title': 'Sample upload.txt','parents':[{"id":fid}]})
uploaded.SetContentString('Sample upload file content')
uploaded.Upload()
print('Uploaded file with ID {}'.format(uploaded.get('id')))
# Out:
# Uploaded file with ID 15MR_fUcbfk_mjb0z7lQ1fcoVoKXWheHp

# %% [markdown]
# Carga un archivo por su ID y luego imprime su contenido.

# %%
uploaded.get('id')
# Out:
# '15MR_fUcbfk_mjb0z7lQ1fcoVoKXWheHp'

# %%
downloaded = drive.CreateFile({'id': uploaded.get('id')})
print('Downloaded content "{}"'.format(downloaded.GetContentString()))
# Out:
# Downloaded content "Sample upload file content"

# %% [markdown]
# # Hojas de cálculo de Google
#
# Los ejemplos de abajo usan la biblioteca de código abierto <a href="https://github.com/burnash/gspread"><code>gspread</code></a> para interactuar con Hojas de cálculo de Google.
#
# Primero, instala el paquete usando <code>pip</code>.

# %%
# !pip install --upgrade --quiet gspread

# %% [markdown]
# Importa la biblioteca, autentica y crea la interfaz para Hojas de cálculo.

# %%
from google.colab import auth
auth.authenticate_user()

import gspread
from oauth2client.client import GoogleCredentials

gc = gspread.authorize(GoogleCredentials.get_application_default())

# %% [markdown]
# A continuación, verás un pequeño conjunto de ejemplos de <code>gspread</code>. Puedes encontrar más ejemplos en la <a href="https://github.com/burnash/gspread#more-examples">página de GitHub de <code>gspread</code></a>.

# %% [markdown]
# ## Crear una hoja nueva con datos de Python

# %%
sh = gc.create('My cool spreadsheet')

# %% [markdown]
# Después de ejecutar la celda anterior, se mostrará una nueva hoja de cálculo con el nombre "My cool spreadsheet" en <a href="https://sheets.google.com/">https://sheets.google.com</a>.
#
# Abre la hoja nueva y agrega datos aleatorios.

# %%
worksheet = gc.open('My cool spreadsheet').sheet1

cell_list = worksheet.range('A1:C2')

import random
for cell in cell_list:
  cell.value = random.randint(1, 10)

worksheet.update_cells(cell_list)
# Out:
# {'spreadsheetId': '1wnh3SdmZRDcpPd1kbyg7UHO_aWN-PDijE8EUOq_bh-E',
#  'updatedCells': 6,
#  'updatedColumns': 3,
#  'updatedRange': "'Hoja 1'!A1:C2",
#  'updatedRows': 2}

# %% [markdown]
# ## Descargar datos de una hoja de cálculo en Python como un DataFrame de Pandas
#
# Vuelve a leer los datos aleatorios que insertamos anteriormente y convierte el resultado en un <a href="https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.html">DataFrame de Pandas</a>.

# %%
worksheet = gc.open('My cool spreadsheet').sheet1

# get_all_values gives a list of rows.
rows = worksheet.get_all_values()
print('******************Lista de datos*********************')
print(rows)

import pandas as pd
dataset=pd.DataFrame.from_records(rows)
print('******************Data Frame*********************')
print(dataset)
# Out:
# ******************Lista de datos*********************
# [['10', '2', '10'], ['3', '5', '6']]
# ******************Data Frame*********************
#     0  1   2
# 0  10  2  10
# 1   3  5   6
